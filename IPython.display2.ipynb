# %% [markdown]
# # IPython.display

# %%
from IPython.display import IFrame, YouTubeVideo, SVG, HTML

# %% [markdown]
# # Display Web page

# %%
IFrame("https://matplotlib.org/examples/color/named_colors.html", width=950, height=450)
# Out:
#         <iframe
#             width="950"
#             height="450"
#             src="https://matplotlib.org/examples/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df.sample(5)
# Out:
#                     name          genus   vore           order conservation  \
# 54       Desert hedgehog    Paraechinus    NaN  Erinaceomorpha           lc
# 25          Patas monkey   Erythrocebus   omni        Primates           lc
# 62            Rock hyrax       Procavia    NaN      Hyracoidea           lc
# 79  Bottle-nosed dolphin       Tursiops  carni         Cetacea          NaN
# 12                Grivet  Cercopithecus   omni        Primates           lc
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 54         10.3        2.7          NaN   13.7   0.0024    0.55
# 25         10.9        1.1          NaN   13.1   0.1150   10.00
# 62          5.4        0.5          NaN   18.6   0.0210    3.60
# 79          5.2        NaN          NaN   18.8      NaN  173.33
# 12         10.0        0.7          NaN   14.0      NaN    4.75

# %%
df.vore.value_counts().plot.barh(color='forestgreen');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4bb0d333707a> in <module>
# ----> 1 df.vore.value_counts().plot.barh(color='forestgreen');
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Display PDF

# %% [markdown]
# https://www.datacamp.com/community/data-science-cheatsheets

# %%
IFrame('http://datacamp-community-prod.s3.amazonaws.com/c06d5eb5-d686-42ae-ba5b-85f5b17b2ed6', width=950, height=450)
# Out:
#         <iframe
#             width="950"
#             height="450"
#             src="http://datacamp-community-prod.s3.amazonaws.com/c06d5eb5-d686-42ae-ba5b-85f5b17b2ed6"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Embed Youtube

# %%
# https: //www.youtube.com/watch?v=WNc3bFQSR00
YouTubeVideo('WNc3bFQSR00', 640, 360)

# %% [markdown]
# # Display HTML

# %%
s='''
<span style=color:red;font-size:150%>Hello</span> <span style=color:blue;font-size:200%>Python</span>
'''
HTML(s)
# Out:
# <span style=color:red;font-size:150%>Hello</span> <span style=color:blue;font-size:200%>Python</span>

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Jennie_Kim_for_Marie_Claire_Korea_Magazine_on_October_9%2C_2018_%282%29.png/340px-Jennie_Kim_for_Marie_Claire_Korea_Magazine_on_October_9%2C_2018_%282%29.png></img>

# %%
s='''
<table class="table table-hover table-set col-3-center table-set-border-yellow">
                <thead>
                <tr>
                    <th></th>
                    <th><strong>ล่าสุด</strong></th>
                    <th><strong>เปลี่ยนแปลง</strong></th>
                    <th><strong>มูลค่า<br>(ลบ.)</strong></th>
                </tr>
                </thead>
                <tbody>
                
                    <tr>
                        <td>
                            
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH" target="_blank">SET</a>
                                
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                1,518.27
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+1.84</td>
                        <td style="text-align: right;">92,889.81</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&amp;language=th&amp;country=TH" target="_blank">SET50</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                949.46
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+1.22</td>
                        <td style="text-align: right;">56,458.64</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET100&amp;language=th&amp;country=TH" target="_blank">SET100</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                2,139.27
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+3.10</td>
                        <td style="text-align: right;">71,119.39</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=sSET&amp;language=th&amp;country=TH" target="_blank">sSET</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                768.30
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+2.42</td>
                        <td style="text-align: right;">4,969.99</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETCLMV&amp;language=th&amp;country=TH" target="_blank">SETCLMV</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                991.79
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+4.62</td>
                        <td style="text-align: right;">34,828.91</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETHD&amp;language=th&amp;country=TH" target="_blank">SETHD</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                1,109.50
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+3.45</td>
                        <td style="text-align: right;">28,072.52</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETTHSI&amp;language=th&amp;country=TH" target="_blank">SETTHSI</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                963.78
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+1.89</td>
                        <td style="text-align: right;">57,622.99</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETWB&amp;language=th&amp;country=TH" target="_blank">SETWB</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                909.87
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-5.46</td>
                        <td style="text-align: right;">12,365.06</td>
                    </tr>
                
                </tbody>
            </table>
'''
HTML(s)
# Out:
# <table class="table table-hover table-set col-3-center table-set-border-yellow">
#                 <thead>
#                 <tr>
#                     <th></th>
#                     <th><strong>ล่าสุด</strong></th>
#                     <th><strong>เปลี่ยนแปลง</strong></th>
#                     <th><strong>มูลค่า<br>(ลบ.)</strong></th>
#                 </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr>
#                         <td>
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH" target="_blank">SET</a>
#
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
#
#
#                                 1,518.27
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-green">+1.84</td>
#                         <td style="text-align: right;">92,889.81</td>
#                     </tr>
#
#                     <tr>
#                         <td>
#
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&amp;language=th&amp;country=TH" target="_blank">SET50</a>
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
#
#
#                                 949.46
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-green">+1.22</td>
#                         <td style="text-align: right;">56,458.64</td>
#                     </tr>
#
#                     <tr>
#                         <td>
#
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET100&amp;language=th&amp;country=TH" target="_blank">SET100</a>
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
#
#
#                                 2,139.27
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-green">+3.10</td>
#                         <td style="text-align: right;">71,119.39</td>
#                     </tr>
#
#                     <tr>
#                         <td>
#
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=sSET&amp;language=th&amp;country=TH" target="_blank">sSET</a>
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
#
#
#                                 768.30
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-green">+2.42</td>
#                         <td style="text-align: right;">4,969.99</td>
#                     </tr>
#
#                     <tr>
#                         <td>
#
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETCLMV&amp;language=th&amp;country=TH" target="_blank">SETCLMV</a>
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
#
#
#                                 991.79
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-green">+4.62</td>
#                         <td style="text-align: right;">34,828.91</td>
#                     </tr>
#
#                     <tr>
#                         <td>
#
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETHD&amp;language=th&amp;country=TH" target="_blank">SETHD</a>
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
#
#
#                                 1,109.50
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-green">+3.45</td>
#                         <td style="text-align: right;">28,072.52</td>
#                     </tr>
#
#                     <tr>
#                         <td>
#
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETTHSI&amp;language=th&amp;country=TH" target="_blank">SETTHSI</a>
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
