# %%
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('https://data.go.th/dataset/8a956917-436d-4afd-a2d4-59e4dd8e906e/resource/329f684b-994d-476b-91a4-62b2ea00f29f/download/pm-24-jan-2021.csv', nrows=100)
df[:100]
# Out:
#     No. announce_date notification_date   sex  age nationality  \
# 0     1     1/12/2020               NaN  หญิง   61       China
# 1     2     1/17/2020               NaN  หญิง   74       China
# 2     3     1/22/2020               NaN  หญิง   73    Thailand
# 3     4     1/22/2020               NaN   ชาย   68       China
# 4     5     1/24/2020               NaN  หญิง   66       China
# ..  ...           ...               ...   ...  ...         ...
# 95   96     3/15/2020               NaN  หญิง   30    Thailand
# 96   97     3/15/2020               NaN   ชาย   31    Thailand
# 97   98     3/15/2020               NaN  หญิง   33    Thailand
# 98   99     3/15/2020               NaN  หญิง   38    Thailand
# 99  100     3/15/2020               NaN  หญิง   38    Thailand
#
#    province_of_isolation province_of_onset district_of_onset  \
# 0          กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# ...

# %%
df[['age', 'nationality']].groupby('nationality').max().plot(kind='bar');
